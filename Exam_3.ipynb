# %% [markdown]
# <a href="https://colab.research.google.com/github/PanasRojpattanadecha/python_dataviz2024/blob/main/Exam_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
path = '/content/drive/MyDrive/Exam_3'

# %%
docter_file_path = os.path.join(path,'Data_Docter_ศ.นพ.ชวลิต.csv')
print(docter_file_path)
# Out:
# /content/drive/MyDrive/Exam_3/Data_Docter_ศ.นพ.ชวลิต.csv

# %%
data_df = pd.read_csv(docter_file_path)
data_df
# Out:
#                                       name  \
# 0     ศ.นพ.ชวลิต ศูนย์มะเร็ง รพ.จุฬาลงกรณ์
# 1                           Nubeer Kithiya
# 2                          วาสนา คุ้มจิตต์
# 3                     Wansook Chompoo Ploy
# 4                              Aphit Aphit
# ...                                    ...
# 1648                           Fear Q'bick
# 1649                          Toei Nittiya
# 1650                       Ouiaii Promsuan
# 1651                      Thanyalak Banboo
# 1652                         Maii Mutchima
#
#                                                comments  ยอดไลค์  \
# 0     กดที่ลิงค์นี้เพื่อเข้าไปอ่านคอมเม้นของโพสต์ครั...      456
# 1     เป็นมะเร็งลำไส้ใหญ่ ระยะที่ 3 ตอนอายุ 26 ค่ะ พ...     1400
# 2     แม่เป็นมะเร็งขั้วปอด ลามขึ้นสมองค่ะ เริ่มแรกที...      402
# 3     #มะเร็งปากมดลูกระยะCINlll เกือบเข้าระยะ 1 ตอนอ...     1600
# 4     ลูกสาวเป็นมะเร็งกระดูก Osteosarcomaช่วงเข่า อา...      480
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1653 entries, 0 to 1652
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             1653 non-null   object
#  1   comments         1653 non-null   object
#  2   ยอดไลค์          1653 non-null   int64
#  3   จำนวนการตอบกลับ  1653 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 51.8+ KB

# %% [markdown]
# # ข้อ 1. Top 3 ประเภทของมะเร็งที่ถูกกล่าวถึงมากที่สุด

# %% [markdown]
# ![สกรีนช็อต 2024-08-26 191113.png](data:image/png;base64,...)

# %%
# กำหนดประเภทของมะเร็งที่สนใจ
cancer_types = ["มะเร็งปากมดลูก", "มะเร็งลำไส้ใหญ่", "มะเร็งเต้านม", "มะเร็งรังไข่", "มะเร็งตับ",
                   "มะเร็งมดลูก", "มะเร็งปอด", "มะเร็งกระดูก", "มะเร็งช่องปาก", "มะเร็งผิวหนัง",
                   "มะเร็งโพรงหลังจมูก", "มะเร็งต่อมลูกหมาก", "มะเร็งกล่องเสียง", "มะเร็งเม็ดเลือดขาว",
                   "มะเร็งต่อมธัยรอยด์", "มะเร็งต่อมน้ำเหลือง", "มะเร็งถุงน้ำดี", "มะเร็งท่อน้ำดี",
                   "มะเร็งตับอ่อน", "มะเร็งระบบประสาท", "มะเร็งทางเดินอาหาร","มะเร็งหลอดอาหาร",
                   "มะเร็งอวัยวะสืบพันธุ์", "มะเร็งขั้วปอด"]

# นับจำนวนครั้งที่มะเร็งแต่ละประเภทถูกกล่าวถึง
cancer_mentions = data['most_mentioned_cancer'].value_counts()
print("\nจำนวนครั้งที่มะเร็งแต่ละประเภทถูกกล่าวถึงมากที่สุด:")
cancer_mentions
# Out:
# จำนวนครั้งที่มะเร็งแต่ละประเภทถูกกล่าวถึงมากที่สุด:
# most_mentioned_cancer
# มะเร็งปากมดลูก         1327
# มะเร็งตับ                62
# มะเร็งเต้านม             62
# มะเร็งปอด                50
# มะเร็งต่อมน้ำเหลือง      39
# มะเร็งเม็ดเลือดขาว       29
# มะเร็งลำไส้ใหญ่          19
# มะเร็งรังไข่             14
# มะเร็งกระดูก             12
# มะเร็งท่อน้ำดี            9
# มะเร็งต่อมลูกหมาก         9
# มะเร็งกล่องเสียง          5
# มะเร็งผิวหนัง             4
# มะเร็งหลอดอาหาร           4
# มะเร็งถุงน้ำดี            3
# มะเร็งช่องปาก             2
# มะเร็งมดลูก               2
# มะเร็งขั้วปอด             1
# Name: count, dtype: int64

# %%
# prompt: เรียงtop5 มะเร็งที่ถูกกล่าวถึงมากที่สุด

top_3_cancers = cancer_mentions.head(3)
print("\nTop 3 มะเร็งที่ถูกกล่าวถึงมากที่สุด:")
top_3_cancers
# Out:
# Top 3 มะเร็งที่ถูกกล่าวถึงมากที่สุด:
# most_mentioned_cancer
# มะเร็งปากมดลูก    1327
# มะเร็งตับ           62
# มะเร็งเต้านม        62
# Name: count, dtype: int64

# %% [markdown]
# # ข้อที่ 2. Top 5 อันดับโพสต์ที่ได้รับยอดไลค์และจำนวนการตอบกลับมากที่สุด

# %%
#5 อันดับโพสต์ที่ได้รับยอดไลค์สูงสุด
top_5_likes = data.nlargest(5, 'ยอดไลค์')[['comments', 'ยอดไลค์']]
print("5 อันดับโพสต์ที่ได้รับยอดไลค์สูงสุด:")
top_5_likes
# Out:
# 5 อันดับโพสต์ที่ได้รับยอดไลค์สูงสุด:
#                                              comments  ยอดไลค์
# 3   #มะเร็งปากมดลูกระยะCINlll เกือบเข้าระยะ 1 ตอนอ...     1600
# 5   ลูกสาว 5 ขวบ เป็นมะเร็งสมองคะ ไม่มีอาการอะไร น...     1500
# 1   เป็นมะเร็งลำไส้ใหญ่ ระยะที่ 3 ตอนอายุ 26 ค่ะ พ...     1400
# 4   ลูกสาวเป็นมะเร็งกระดูก Osteosarcomaช่วงเข่า อา...      480
# 46  ผมเป็นมะเร็งเม็ดสีผิวหนังชนิดร้ายแรง(Melanoma)...      477

# %%
#5 อันดับโพสต์ที่มีจำนวนการตอบกลับมากที่สุด
top_5_replies = data.nlargest(5, 'จำนวนการตอบกลับ')[['comments', 'จำนวนการตอบกลับ']]
print("5 อันดับโพสต์ที่มีจำนวนการตอบกลับมากที่สุด:")
top_5_replies
# Out:
# 5 อันดับโพสต์ที่มีจำนวนการตอบกลับมากที่สุด:
#                                               comments  จำนวนการตอบกลับ
# 1    เป็นมะเร็งลำไส้ใหญ่ ระยะที่ 3 ตอนอายุ 26 ค่ะ พ...               70
# 3    #มะเร็งปากมดลูกระยะCINlll เกือบเข้าระยะ 1 ตอนอ...               44
# 22   สำหรับมะเร็งปากมดลูก แนะนำให้ตรวจภายในเป็นประจ...               31
# 46   ผมเป็นมะเร็งเม็ดสีผิวหนังชนิดร้ายแรง(Melanoma)...               30
# 113  ผมเป็นมะเร็งลำไส้ใหญ่ระยะที่ 3 (ปัจจุบันรักษาห...               28
